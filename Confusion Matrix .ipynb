# %%
#Hate type 8 models
import itertools
import numpy as np
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

test=pd.read_json('8models_type/test_unseen_type.jsonl',lines="true")
y_true = test["label"].to_list()

pred=pd.read_csv("8models_type/submission (3).csv")
y_pred=pred["label"].to_list()

cm=confusion_matrix(y_true, y_pred)

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    #print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.figure(figsize=(30,10))

    np.set_printoptions(precision=2)

class_names=[0,1,2,3,4,5,6,7]
# Plot non-normalized confusion matrix
plt.figure(figsize=(30,10))
plot_confusion_matrix(cm, classes=class_names,title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure(figsize=(30,10))
#plot_confusion_matrix(cm, classes=class_names, normalize=True,title='Normalized confusion matrix')
plot_confusion_matrix(cm, classes=class_names, normalize=True)



plt.show()

# %%
#Hate type 8 models
test=pd.read_json('8models_type/test_unseen_type.jsonl',lines="true")
y_true = test["label"].to_list()

pred=pd.read_csv("8models_type/submission (3).csv")
y_pred=pred["label"].to_list()
f1_score(y_true, y_pred, average='weighted')
# Out:
# 0.4302117111373774

# %%
#Hate type 27 models
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

test=pd.read_json('27models_type/test_unseen_type.jsonl',lines="true")
y_true = test["label"].to_list()

pred=pd.read_csv("27models_type/submission (2).csv")
y_pred=pred["label"].to_list()

cm=confusion_matrix(y_true, y_pred)

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    #print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.figure(figsize=(30,10))

    np.set_printoptions(precision=2)

class_names=[0,1,2,3,4,5,6,7]
# Plot non-normalized confusion matrix
plt.figure(figsize=(30,10))
plot_confusion_matrix(cm, classes=class_names,title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure(figsize=(30,10))
#plot_confusion_matrix(cm, classes=class_names, normalize=True,title='Normalized confusion matrix')
plot_confusion_matrix(cm, classes=class_names, normalize=True)



plt.show()

# %%
#Hate type 27 models
test=pd.read_json('27models_type/test_unseen_type.jsonl',lines="true")
y_true = test["label"].to_list()

pred=pd.read_csv("27models_type/submission (2).csv")
y_pred=pred["label"].to_list()
f1_score(y_true, y_pred, average='weighted')
# Out:
# 0.40052574859622214

# %%
#Protected Category 8 models
import itertools
import numpy as np
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

test=pd.read_json('8models_cat/test_unseen_cat.jsonl',lines="true")
y_true = test["label"].to_list()

pred=pd.read_csv("8models_cat/submission (3).csv")
y_pred=pred["label"].to_list()

cm=confusion_matrix(y_true, y_pred)

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    #print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.figure(figsize=(30,10))

    np.set_printoptions(precision=2)

class_names=[0,1,2,3,4,5]
# Plot non-normalized confusion matrix
plt.figure(figsize=(30,10))
plot_confusion_matrix(cm, classes=class_names,title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure(figsize=(30,10))
#plot_confusion_matrix(cm, classes=class_names, normalize=True,title='Normalized confusion matrix')
plot_confusion_matrix(cm, classes=class_names, normalize=True)



plt.show()

# %%
#Protected Category 8 models
test=pd.read_json('8models_cat/test_unseen_cat.jsonl',lines="true")
y_true = test["label"].to_list()

pred=pd.read_csv("8models_cat/submission (3).csv")
y_pred=pred["label"].to_list()
f1_score(y_true, y_pred, average='weighted')
# Out:
# 0.5355845560760193

# %%
#Protected Category 20 models
import itertools
import numpy as np
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

test=pd.read_json('20models_cat/test_unseen_cat.jsonl',lines="true")
y_true = test["label"].to_list()

pred=pd.read_csv("20models_cat/submission (3).csv")
y_pred=pred["label"].to_list()

cm=confusion_matrix(y_true, y_pred)

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    #print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.figure(figsize=(30,10))

    np.set_printoptions(precision=2)

class_names=[0,1,2,3,4,5]
# Plot non-normalized confusion matrix
plt.figure(figsize=(30,10))
plot_confusion_matrix(cm, classes=class_names,title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure(figsize=(30,10))
#plot_confusion_matrix(cm, classes=class_names, normalize=True,title='Normalized confusion matrix')
plot_confusion_matrix(cm, classes=class_names, normalize=True)



plt.show()

# %%
#Protected Category 8 models
test=pd.read_json('20models_cat/test_unseen_cat.jsonl',lines="true")
y_true = test["label"].to_list()

pred=pd.read_csv("20models_cat/submission (3).csv")
y_pred=pred["label"].to_list()
f1_score(y_true, y_pred, average='weighted')
# Out:
# 0.5394666922098247

# %%
pwd
# Out:
# '/Users/danny/Desktop/SoSe22/Bachelor/prediction results'

# %%
ls ../binary_results/
# Out:
# image_only/                    unimodals_metrics final.ipynb
# text_only/                     unimodals_metrics.ipynb

# %%
#Binary Text Only Hate Type 
import itertools
import numpy as np
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

test=pd.read_json('27models_type/test_unseen_type.jsonl',lines="true")
y_true = test["label"].to_list()

pred=pd.read_csv("../binary_results/text_only/hate_type/binary_text_type.csv")
y_pred=pred["final_label"].to_list()

cm=confusion_matrix(y_true, y_pred)

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    #print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.figure(figsize=(30,10))

    np.set_printoptions(precision=2)

class_names=[0,1,2,3,4,5,6,7]
# Plot non-normalized confusion matrix
plt.figure(figsize=(30,10))
plot_confusion_matrix(cm, classes=class_names,title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure(figsize=(30,10))
#plot_confusion_matrix(cm, classes=class_names, normalize=True,title='Normalized confusion matrix')
plot_confusion_matrix(cm, classes=class_names, normalize=True)



plt.show()

# %%
#Binary Text Only Hate Type 
from sklearn.metrics import f1_score

test=pd.read_json('27models_type/test_unseen_type.jsonl',lines="true")
y_true = test["label"].to_list()

pred=pd.read_csv("../binary_results/text_only/hate_type/binary_text_type.csv")
y_pred=pred["final_label"].to_list()

f1_score(y_true, y_pred, average='weighted')
# Out:
# 0.057360622311602716

# %%
#Binary Vision Only Hate Type 
import itertools
import numpy as np
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

test=pd.read_json('27models_type/test_unseen_type.jsonl',lines="true")
y_true = test["label"].to_list()

pred=pd.read_csv("../binary_results/image_only/hate_type/binary_vision_type.csv")
y_pred=pred["final_label"].to_list()

cm=confusion_matrix(y_true, y_pred)

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    #print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.figure(figsize=(30,10))

    np.set_printoptions(precision=2)

class_names=[0,1,2,3,4,5,6,7]
# Plot non-normalized confusion matrix
plt.figure(figsize=(30,10))
plot_confusion_matrix(cm, classes=class_names,title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure(figsize=(30,10))
#plot_confusion_matrix(cm, classes=class_names, normalize=True,title='Normalized confusion matrix')
plot_confusion_matrix(cm, classes=class_names, normalize=True)



plt.show()

# %%
#Binary Vision Only Hate Type 

test=pd.read_json('27models_type/test_unseen_type.jsonl',lines="true")
y_true = test["label"].to_list()

pred=pd.read_csv("../binary_results/image_only/hate_type/binary_vision_type.csv")
y_pred=pred["final_label"].to_list()

f1_score(y_true, y_pred, average='weighted')
# Out:
# 0.061210266015758005

# %%
#Binary Text Only Categories
import itertools
import numpy as np
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

test=pd.read_json('20models_cat/test_unseen_cat.jsonl',lines="true")
y_true = test["label"].to_list()

pred=pd.read_csv("../binary_results/text_only/cat/binary_text_cat.csv")
y_pred=pred["final_label"].to_list()

cm=confusion_matrix(y_true, y_pred)

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    #print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.figure(figsize=(30,10))

    np.set_printoptions(precision=2)

class_names=[0,1,2,3,4,5]
# Plot non-normalized confusion matrix
plt.figure(figsize=(30,10))
plot_confusion_matrix(cm, classes=class_names,title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure(figsize=(30,10))
#plot_confusion_matrix(cm, classes=class_names, normalize=True,title='Normalized confusion matrix')
plot_confusion_matrix(cm, classes=class_names, normalize=True)



plt.show()

# %%
#Binary Text Only Categories
test=pd.read_json('20models_cat/test_unseen_cat.jsonl',lines="true")
y_true = test["label"].to_list()

pred=pd.read_csv("../binary_results/text_only/cat/binary_text_cat.csv")
y_pred=pred["final_label"].to_list()

f1_score(y_true, y_pred, average='weighted')
# Out:
# 0.07134807393632969

# %%
#Binary Text Only Categories
import itertools
import numpy as np
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

test=pd.read_json('20models_cat/test_unseen_cat.jsonl',lines="true")
y_true = test["label"].to_list()

pred=pd.read_csv("../binary_results/image_only/cat/binary_vision_cat.csv")
y_pred=pred["final_label"].to_list()

cm=confusion_matrix(y_true, y_pred)

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    #print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.figure(figsize=(30,10))

    np.set_printoptions(precision=2)

class_names=[0,1,2,3,4,5]
# Plot non-normalized confusion matrix
plt.figure(figsize=(30,10))
plot_confusion_matrix(cm, classes=class_names,title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure(figsize=(30,10))
#plot_confusion_matrix(cm, classes=class_names, normalize=True,title='Normalized confusion matrix')
plot_confusion_matrix(cm, classes=class_names, normalize=True)



plt.show()

# %%
#Binary Vision Only Categories
test=pd.read_json('20models_cat/test_unseen_cat.jsonl',lines="true")
y_true = test["label"].to_list()

pred=pd.read_csv("../binary_results/image_only/cat/binary_vision_cat.csv")
y_pred=pred["final_label"].to_list()

f1_score(y_true, y_pred, average='weighted')
# Out:
# 0.14617600682263598
